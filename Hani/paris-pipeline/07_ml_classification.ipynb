# %% [markdown]
# # 07 — ML Classification (Paris)
#
# Trains Logistic Regression, XGBoost, and Random Forest to classify
# grid cells as **residential**, **commercial**, or **industrial**.
#
# **Features (X):**
# - `amenity_density`, `amenity_ratio_food_drink` (OSM)
# - `avg_height`, `avg_floors`, `avg_construction_year`, `building_count`, `residential_ratio` (EUBUCCO)
# - `landuse_entropy` (EUBUCCO)
# - `tourism_density` (OSM)
# - `shop_density_km2`, `brand_ratio` (OSM)
#
# **Target (Y):** `zone_type` from notebook 01 (residential / commercial / industrial)
#
# **Input:** `csv/Paris/combined_grid.csv`
#
# **Output:** plots to `outputs/Paris/`, predictions to `csv/Paris/07_predictions.csv`

# %%
PARIS_CONFIG = "paris.json"
PLOTS_DIR    = "outputs/Paris"

# %%
import matplotlib
matplotlib.use("Agg")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import os

sns.set(color_codes=True, rc={"figure.figsize": (10, 8)})
os.makedirs(PLOTS_DIR, exist_ok=True)

with open(PARIS_CONFIG, encoding="utf-8") as f:
    config = json.load(f)

CSV_DIR = config["csv_dir"]
CSV_PATH = f"{CSV_DIR}/combined_grid.csv"

df = pd.read_csv(CSV_PATH, dtype={"cell_id": str})
print(f"Loaded {len(df)} rows x {df.shape[1]} cols")
print(f"\nZone type distribution:")
print(df["zone_type"].value_counts().to_string())
# Out:
# Loaded 120331 rows x 16 cols
#
# Zone type distribution:
# zone_type
# residential    101989
# industrial      10458
# commercial       7458
# mixed             426

# %%
# ── Keep only target labels ───────────────────────────
TARGET_LABELS = config["target_labels"]  # ["residential", "commercial", "industrial"]
df = df[df["zone_type"].isin(TARGET_LABELS)].copy()
df["label"] = df["zone_type"]
print(f"After filtering to target labels: {len(df)} cells")
print(df["label"].value_counts().to_string())
# Out:
# After filtering to target labels: 119905 cells
# label
# residential    101989
# industrial      10458
# commercial       7458

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 119905 entries, 0 to 120330
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   cell_id                   119905 non-null  str
#  1   cell_lat                  119905 non-null  float64
#  2   cell_lon                  119905 non-null  float64
#  3   zone_type                 119905 non-null  str
#  4   cell_building_count       119905 non-null  int64
#  5   amenity_density           119905 non-null  float64
#  6   amenity_ratio_food_drink  119905 non-null  float64
#  7   avg_height                119905 non-null  float64
#  8   avg_floors                119905 non-null  float64
#  9   avg_construction_year     106680 non-null  float64
#  10  building_count            119905 non-null  int64
#  11  residential_ratio         119905 non-null  float64
#  12  landuse_entropy           119905 non-null  float64
#  13  tourism_density           119905 non-null  float64
#  14  shop_density_km2          119905 non-null  float64
#  15  brand_ratio               119905 non-null  float64
#  16  label                     119905 non-null  str
# dtypes: float64(12), int64(2), str(3)
# memory usage: 20.2 MB

# %%
print(f"Total rows: {len(df)}")
print("\nNull counts per column:")
print(df.isnull().sum())
# Out:
# Total rows: 119905
#
# Null counts per column:
# cell_id                         0
# cell_lat                        0
# cell_lon                        0
# zone_type                       0
# cell_building_count             0
# amenity_density                 0
# amenity_ratio_food_drink        0
# avg_height                      0
# avg_floors                      0
# avg_construction_year       13225
# building_count                  0
# residential_ratio               0
# landuse_entropy                 0
# tourism_density                 0
# shop_density_km2                0
# brand_ratio                     0
# label                           0
# dtype: int64

# %%
df = df_clean.dropna()
print(f"Rows after dropping nulls: {len(df_clean)}")
# Out:
# Rows after dropping nulls: 106680

# %%
print(f"Total rows: {len(df_clean)}")
print("\nNull counts per column:")
print(df_clean.isnull().sum())
# Out:
# Total rows: 106680
#
# Null counts per column:
# cell_id                     0
# cell_lat                    0
# cell_lon                    0
# zone_type                   0
# cell_building_count         0
# amenity_density             0
# amenity_ratio_food_drink    0
# avg_height                  0
# avg_floors                  0
# avg_construction_year       0
# building_count              0
# residential_ratio           0
# landuse_entropy             0
# tourism_density             0
# shop_density_km2            0
# brand_ratio                 0
# label                       0
# dtype: int64

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 106680 entries, 0 to 120330
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   cell_id                   106680 non-null  str
#  1   cell_lat                  106680 non-null  float64
#  2   cell_lon                  106680 non-null  float64
#  3   zone_type                 106680 non-null  str
#  4   cell_building_count       106680 non-null  int64
#  5   amenity_density           106680 non-null  float64
#  6   amenity_ratio_food_drink  106680 non-null  float64
#  7   avg_height                106680 non-null  float64
#  8   avg_floors                106680 non-null  float64
#  9   avg_construction_year     106680 non-null  float64
#  10  building_count            106680 non-null  int64
#  11  residential_ratio         106680 non-null  float64
#  12  landuse_entropy           106680 non-null  float64
#  13  tourism_density           106680 non-null  float64
#  14  shop_density_km2          106680 non-null  float64
#  15  brand_ratio               106680 non-null  float64
#  16  label                     106680 non-null  str
# dtypes: float64(12), int64(2), str(3)
# memory usage: 18.0 MB

# %%
print(df_clean["label"].value_counts().to_string())
# Out:
# label
# residential    96123
# commercial      5390
# industrial      5167

# %%
_exclude = [c.strip() for c in EXCLUDE_COLS.split(",") if c.strip() in df.columns]
df = df.drop(columns=_exclude) if _exclude else df.copy()

# Drop columns that are 100% null
_all_null = [c for c in df.columns if df[c].isna().all()]
if _all_null:
    df = df.drop(columns=_all_null)
    print(f"Dropped 100% null columns: {_all_null}")

# Impute partially null numeric columns with median
_num_cols = df.select_dtypes(include="number").columns
for c in _num_cols:
    n_null = df[c].isna().sum()
    if n_null > 0:
        _med = df[c].median()
        df[c] = df[c].fillna(_med)
        print(f"Imputed {c}: {n_null} nulls → median {_med:.2f}")

# Drop remaining rows with nulls in non-numeric columns
df = df.dropna()

print(f"\nDropped columns: {_exclude}")
print(f"Rows remaining: {len(df)}")
print(f"\nNull counts after cleaning:")
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 _exclude = [c.strip() for c in EXCLUDE_COLS.split(",") if c.strip() in df.columns]
#       2 df = df.drop(columns=_exclude) if _exclude else df.copy()
#       3
#       4 # Drop columns that are 100% null
#
# NameError: name 'EXCLUDE_COLS' is not defined

# %%
# ── EDA: class distribution ────────────────────────────
fig, ax = plt.subplots(figsize=(8, 5))
sns.countplot(data=df, x="label", ax=ax)
ax.set_title("Paris — Zone Type Distribution")
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/01_countplot_zone_type.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Hani\AppData\Local\Temp\ipykernel_22988\2239869048.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# ── Feature columns ───────────────────────────────────
FEATURE_COLS = [
    "amenity_density",
    "amenity_ratio_food_drink",
    "avg_height",
    "avg_floors",
    "avg_construction_year",
    "building_count",
    "residential_ratio",
    "landuse_entropy",
    "tourism_density",
    "shop_density_km2",
    "brand_ratio",
]

# Only use columns that exist
FEATURE_COLS = [c for c in FEATURE_COLS if c in df.columns]
print(f"Features used: {FEATURE_COLS}")
# Out:
# Features used: ['amenity_density', 'amenity_ratio_food_drink', 'avg_height', 'avg_floors', 'avg_construction_year', 'building_count', 'residential_ratio', 'landuse_entropy', 'tourism_density', 'shop_density_km2', 'brand_ratio']

# %%
# ── EDA: feature boxplots ─────────────────────────────
n_feats = len(FEATURE_COLS)
n_cols  = 3
n_rows  = (n_feats + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, 4 * n_rows))
fig.suptitle("Paris — Feature Distributions by Zone Type", fontsize=14)
for ax, feat in zip(axes.flatten(), FEATURE_COLS):
    sns.boxplot(data=df, x="label", y=feat, ax=ax)
    ax.set_title(feat)
for ax in axes.flatten()[n_feats:]:
    ax.set_visible(False)
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/02_feature_boxplots.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\Hani\AppData\Local\Temp\ipykernel_22988\195895857.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# ── Correlation heatmap ───────────────────────────────
fig, ax = plt.subplots(figsize=(12, 10))
corr = df[FEATURE_COLS].corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap="RdBu_r", center=0,
            square=True, ax=ax, vmin=-1, vmax=1)
ax.set_title("Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/03_correlation_heatmap.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ── Prepare X and Y ───────────────────────────────────
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score

X = df[FEATURE_COLS].copy().fillna(df[FEATURE_COLS].median())
encoder = LabelEncoder()
y = encoder.fit_transform(df["label"])
class_names = list(encoder.classes_)

print(f"Classes:  {class_names}")
print(f"X shape:  {X.shape}")

scaler   = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)
print(f"Train: {X_train.shape[0]}   Test: {X_test.shape[0]}")

# %%
# ── Logistic Regression ───────────────────────────────
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

lr = LogisticRegression(max_iter=1000, class_weight="balanced", random_state=42)
scores = cross_val_score(lr, X_train, y_train, cv=5)
print(f"LR Cross-val: {scores.mean():.3f} (+/- {scores.std():.3f})")

lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)
print(f"Test accuracy: {lr.score(X_test, y_test):.3f}")
print(classification_report(y_test, y_pred_lr, target_names=class_names))

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, y_pred_lr),
                                colorbar=True, show_absolute=True, show_normed=True,
                                class_names=class_names)
plt.title("Logistic Regression — Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/04_confusion_matrix_lr.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ── XGBoost ───────────────────────────────────────────
import xgboost as xgb

xgb_model = xgb.XGBClassifier(random_state=42, eval_metric="mlogloss")
scores = cross_val_score(xgb_model, X_train, y_train, cv=5)
print(f"XGB Cross-val: {scores.mean():.3f} (+/- {scores.std():.3f})")

xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)
print(f"Test accuracy: {xgb_model.score(X_test, y_test):.3f}")
print(classification_report(y_test, y_pred_xgb, target_names=class_names))

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, y_pred_xgb),
                                colorbar=True, show_absolute=True, show_normed=True,
                                class_names=class_names)
plt.title("XGBoost — Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/05_confusion_matrix_xgb.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ── Random Forest ─────────────────────────────────────
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(class_weight="balanced", random_state=42)
scores = cross_val_score(rf, X_train, y_train, cv=5)
print(f"RF Cross-val: {scores.mean():.3f} (+/- {scores.std():.3f})")

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print(f"Test accuracy: {rf.score(X_test, y_test):.3f}")
print(classification_report(y_test, y_pred_rf, target_names=class_names))

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, y_pred_rf),
                                colorbar=True, show_absolute=True, show_normed=True,
                                class_names=class_names)
plt.title("Random Forest — Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/06_confusion_matrix_rf.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ── Feature importance ────────────────────────────────
importances = pd.Series(rf.feature_importances_, index=FEATURE_COLS).sort_values(ascending=True)
fig, ax = plt.subplots(figsize=(10, 6))
importances.plot(kind="barh", ax=ax)
ax.set_title("Random Forest — Feature Importance (Paris)")
ax.set_xlabel("Importance")
plt.tight_layout()
plt.savefig(f"{PLOTS_DIR}/07_feature_importance_rf.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ── Export predictions ────────────────────────────────
X_all        = df[FEATURE_COLS].fillna(df[FEATURE_COLS].median())
X_all_scaled = scaler.transform(X_all)

df["predicted_zone"] = encoder.inverse_transform(rf.predict(X_all_scaled))
proba = rf.predict_proba(X_all_scaled)

for i, cls in enumerate(encoder.classes_):
    df[f"prob_{cls}"] = proba[:, i].round(4)
df["confidence"] = proba.max(axis=1).round(4)

pred_cols = ["cell_id", "cell_lat", "cell_lon", "zone_type", "predicted_zone", "confidence"] \
           + [f"prob_{c}" for c in encoder.classes_]
predictions = df[pred_cols]

pred_path = f"{CSV_DIR}/07_predictions.csv"
predictions.to_csv(pred_path, index=False, encoding="utf-8")
print(f"Saved predictions: {pred_path} ({len(predictions)} cells)")
print(predictions["predicted_zone"].value_counts().to_string())
